# %% [markdown]
# <a href="https://colab.research.google.com/github/chenweioh/GCP-Inspector-Toolkit/blob/main/List_folder_and_files_RAR_Fail.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get -qq install python3-rarfile

from google.colab import files

uploaded = files.upload()
rar_path = list(uploaded.keys())[0]

import rarfile

def list_rar_contents(rar_path):
    with rarfile.RarFile(rar_path, 'r') as archive:
        for file_info in archive.infolist():
            print(f"Name: {file_info.filename} | Size: {file_info.file_size} bytes | Type: {'Folder' if file_info.isdir() else 'File'}")

list_rar_contents(rar_path)
# Out:
# Selecting previously unselected package libarchive-tools.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../libarchive-tools_3.6.0-1ubuntu1_amd64.deb ...
# Unpacking libarchive-tools (3.6.0-1ubuntu1) ...
# Selecting previously unselected package python3-rarfile.
# Preparing to unpack .../python3-rarfile_3.1-1_all.deb ...
# Unpacking python3-rarfile (3.1-1) ...
# Setting up libarchive-tools (3.6.0-1ubuntu1) ...
# Setting up python3-rarfile (3.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...
#      <input type="file" id="files-d3e147d8-334e-47f8-8b23-e54f9dc52909" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3e147d8-334e-47f8-8b23-e54f9dc52909">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# ...

# %%
from google.colab import files
import zipfile
import io

# Upload a ZIP file from your local machine
uploaded = files.upload()

# Loop through all uploaded files
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")

    # Analyze the contents of each uploaded ZIP file
    with zipfile.ZipFile(io.BytesIO(uploaded[filename]), 'r') as zip_archive:
        for file_info in zip_archive.infolist():
            # Extract and analyze the contents of each file in the ZIP archive
            with zip_archive.open(file_info.filename) as file:
                try:
                    # Try decoding with UTF-8
                    file_contents = file.read().decode('utf-8')
                except UnicodeDecodeError:
                    # If decoding with UTF-8 fails, try another encoding (e.g., latin-1)
                    file_contents = file.read().decode('latin-1')

                # You can process 'file_contents' here as needed
                # For example, you can print the contents of each file
                print(f"{file_info.filename}")
# Out:
#      <input type="file" id="files-8bc241a2-1fa3-4f0e-8cd1-169eb57c6c44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8bc241a2-1fa3-4f0e-8cd1-169eb57c6c44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
